# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# 1都6県の大学、高等教育機関を抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity='university' and
    poly.name_1 IN('Tokyo', 'Kanagawa', 'Saitama', 'Chiba', 'Ibaraki', 'Gunma', 'Tochigi') and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#          osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    1420739594   None           None             None               None
# 1    1420729658   None           None             None               None
# 2    1420729666   None           None             None               None
# 3    1420740359   None           None             None               None
# 4    1420743970   None           None             None               None
# ..          ...    ...            ...              ...                ...
# 347  6817255916   None           None             None               None
# 348  2581968532   None           None             None               None
# 349  7746636843   None           None             None               None
# 350  7133354586   None           None             None               None
# 351  7746763952   None           None             None               None
#
#     admin_level aerialway aeroway     amenity  area barrier bicycle brand  \
# 0          None      None    None  university  None    None    None  None
# 1          None      None    None  university  None    None    None  None
# 2          None      None    None  university  None    None    None  None
# 3          None      None    None  university  None    None    None  None
# 4          None      None    None  university  None    None    None  None
# ..          ...       ...     ...         ...   ...     ...     ...   ...
# 347        None      None    None  university  None    None    None  None
# 348        None      None    None  university  None    None    None  None
# 349        None      None    None  university  None    None    None  None
# 350        None      None    None  university  None    None    None  None
# 351        None      None    None  university  None    None    None  None
#
#     bridge boundary building capital construction covered culvert cutting  \
# 0     None     None     None    None         None    None    None    None
# 1     None     None     None    None         None    None    None    None
# 2     None     None     None    None         None    None    None    None
# 3     None     None     None    None         None    None    None    None
# 4     None     None     None    None         None    None    None    None
# ..     ...      ...      ...     ...          ...     ...     ...     ...
# 347   None     None     None    None         None    None    None    None
# 348   None     None     None    None         None    None    None    None
# 349   None     None     None    None         None    None    None    None
# 350   None     None     None    None         None    None    None    None
# 351   None     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 347         None    None  None       None  None             None    None
# 348         None    None  None       None  None             None    None
# 349         None    None  None       None  None             None    None
# 350         None    None  None       None  None             None    None
# 351         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
# 2      None     None  None         None     None    None  None    None  None
# 3      None     None  None         None     None    None  None    None  None
# 4      None     None  None         None     None    None  None    None  None
# ..      ...      ...   ...          ...      ...     ...   ...     ...   ...
# 347    None     None  None         None     None    None  None    None  None
# 348    None     None  None         None     None    None  None    None  None
# 349    None     None  None         None     None    None  None    None  None
# 350    None     None  None         None     None    None  None    None  None
# 351    None     None  None         None     None    None  None    None  None
#
#     man_made military motorcar                       name natural office  \
# 0       None     None     None                 敬愛大学（国際学部）    None   None
# 1       None     None     None             千葉科学大学（危機管理学部）    None   None
# 2       None     None     None                千葉科学大学（薬学部）    None   None
# 3       None     None     None               東京基督教大学（神学部）    None   None
# 4       None     None     None  ＬＥＣ東京リーガルマインド大学（総合キャリア学部）    None   None
# ..       ...      ...      ...                        ...     ...    ...
# 347     None     None     None                  東京大学栃本作業所    None   None
# 348     None     None     None                  東京大学千葉演習林    None   None
# 349     None     None     None            東京大学千葉演習林 天津事務所    None   None
# 350     None     None     None                     亀田医療大学    None   None
# 351     None     None     None            東京大学千葉演習林 札郷作業所    None   None
#
#     oneway               operator place   poi population power power_source  \
# 0     None                   None  None  None       None  None         None
# 1     None                   None  None  None       None  None         None
# 2     None                   None  None  None       None  None         None
# 3     None                   None  None  None       None  None         None
# 4     None                   None  None  None       None  None         None
# ..     ...                    ...   ...   ...        ...   ...          ...
# 347   None                   None  None  None       None  None         None
# 348   None                   東京大学  None  None       None  None         None
# 349   None  東京大学大学院農学生命科学研究科附属演習林  None  None       None  None         None
# 350   None                   None  None  None       None  None         None
# 351   None                   None  None  None       None  None         None
#
#     public_transport railway   ref religion route service  shop sport surface  \
# 0               None    None  None     None  None    None  None  None    None
# 1               None    None  None     None  None    None  None  None    None
# 2               None    None  None     None  None    None  None  None    None
# 3               None    None  None     None  None    None  None  None    None
# 4               None    None  None     None  None    None  None  None    None
# ..               ...     ...   ...      ...   ...     ...   ...   ...     ...
# 347             None    None  None     None  None    None  None  None    None
# 348             None    None  None     None  None    None  None  None    None
# 349             None    None  None     None  None    None  None  None    None
# 350             None    None  None     None  None    None  None  None    None
# 351             None    None  None     None  None    None  None  None    None
#
#      toll tourism tower:type tunnel water waterway wetland width  wood  \
# 0    None    None       None   None  None     None    None  None  None
# 1    None    None       None   None  None     None    None  None  None
# 2    None    None       None   None  None     None    None  None  None
# 3    None    None       None   None  None     None    None  None  None
# 4    None    None       None   None  None     None    None  None  None
# ..    ...     ...        ...    ...   ...      ...     ...   ...   ...
# 347  None    None       None   None  None     None    None  None  None
# 348  None    None       None   None  None     None    None  None  None
# 349  None    None       None   None  None     None    None  None  None
# 350  None    None       None   None  None     None    None  None  None
# 351  None    None       None   None  None     None    None  None  None
#
#     z_order                               way
# 0      None  POINT (15607791.215 4257300.795)
# 1      None  POINT (15678419.202 4260265.364)
# 2      None  POINT (15678419.202 4260265.364)
# 3      None   POINT (15598722.84 4271780.244)
# 4      None    POINT (15597656.8 4247356.415)
# ..      ...                               ...
# 347    None  POINT (15457291.082 4292470.871)
# 348    None  POINT (15601012.159 4185610.035)
# 349    None  POINT (15601797.974 4181093.321)
# 350    None  POINT (15595859.046 4177735.094)
# 351    None  POINT (15600671.989 4191110.753)
#
# [352 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57e6e06c42b27da2532410e9b206c7a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57e6e06c42b27da2532410e9b206c7a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57e6e06c42b27da2532410e9b206c7a4 = L.map(
#                 &quot;map_57e6e06c42b27da2532410e9b206c7a4&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32079393f38bb595b474710826eea322 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_32079393f38bb595b474710826eea322.addTo(map_57e6e06c42b27da2532410e9b206c7a4);
#
#
#             var marker_91d7f3dda869d238e222c03a6187df20 = L.marker(
#                 [35.68453899970566, 140.207174],
#                 {
# }
#             ).addTo(map_57e6e06c42b27da2532410e9b206c7a4);
#
#
#         var popup_54a2973277b39f5e87f965e1be1f7da3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dc0c7895578e3ec4b2cb9da871c1685 = $(`&lt;div id=&quot;html_3dc0c7895578e3ec4b2cb9da871c1685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;敬愛大学（国際学部）&lt;/div&gt;`)[0];
#                 popup_54a2973277b39f5e87f965e1be1f7da3.setContent(html_3dc0c7895578e3ec4b2cb9da871c1685);
#
#
#
#         marker_91d7f3dda869d238e222c03a6187df20.bindPopup(popup_54a2973277b39f5e87f965e1be1f7da3)
#         ;
#
#
#
#
#             var marker_e4d2d116e10f50a566f83f9f2207abf4 = L.marker(
#                 [35.706166999707605, 140.841636],
#                 {
# }
#             ).addTo(map_57e6e06c42b27da2532410e9b206c7a4);
#
#
#         var popup_c60ab5844c89fce55f0222c73344ac7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2bffe780b09cc676c322fb72b29902f = $(`&lt;div id=&quot;html_f2bffe780b09cc676c322fb72b29902f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;千葉科学大学（危機管理学部）&lt;/div&gt;`)[0];
#                 popup_c60ab5844c89fce55f0222c73344ac7d.setContent(html_f2bffe780b09cc676c322fb72b29902f);
#
#
#
#         marker_e4d2d116e10f50a566f83f9f2207abf4.bindPopup(popup_c60ab5844c89fce55f0222c73344ac7d)
#         ;
#
#
#
#
#             var marker_c9677b77300fe26f89c3fcf1058147bf = L.marker(
#                 [35.706166999707605, 140.841636],
#                 {
# }
#             ).addTo(map_57e6e06c42b27da2532410e9b206c7a4);
#
#
#         var popup_11b73d1c0e0ef4150b7ec886496cae51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9464dab2bacace3f92e836c33bc24f35 = $(`&lt;div id=&quot;html_9464dab2bacace3f92e836c33bc24f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;千葉科学大学（薬学部）&lt;/div&gt;`)[0];
#                 popup_11b73d1c0e0ef4150b7ec886496cae51.setContent(html_9464dab2bacace3f92e836c33bc24f35);
#
#
#
#         marker_c9677b77300fe26f89c3fcf1058147bf.bindPopup(popup_11b73d1c0e0ef4150b7ec886496cae51)
#         ;
#
#
#
#
#             var marker_482531581e12edf7583b06044f758c99 = L.marker(
#                 [35.790118099715315, 140.1257114],
#                 {
# }
#             ).addTo(map_57e6e06c42b27da2532410e9b206c7a4);
#
#
#         var popup_92e65fb6255d1b36b8364c1dcdae03f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c2ecb09fb05417f08dab12d730f8fa6 = $(`&lt;div id=&quot;html_4c2ecb09fb05417f08dab12d730f8fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東京基督教大学（神学部）&lt;/div&gt;`)[0];
#                 popup_92e65fb6255d1b36b8364c1dcdae03f9.setContent(html_4c2ecb09fb05417f08dab12d730f8fa6);
#
#
#
#         marker_482531581e12edf7583b06044f758c99.bindPopup(popup_92e65fb6255d1b36b8364c1dcdae03f9)
#         ;
#
#
#
#
#             var marker_837e8a2fdfd5686c7e46b397655e7101 = L.marker(
#                 [35.611946999699214, 140.116135],
#                 {
# }
#             ).addTo(map_57e6e06c42b27da2532410e9b206c7a4);
#
#
#         var popup_271028ee45f3d1fb0f3f56ee4ef0b15c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbd4aca67d57ff703b8ec4ac42dc3ec4 = $(`&lt;div id=&quot;html_bbd4aca67d57ff703b8ec4ac42dc3ec4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ＬＥＣ東京リーガルマインド大学（総合キャリア学部）&lt;/div&gt;`)[0];
#                 popup_271028ee45f3d1fb0f3f56ee4ef0b15c.setContent(html_bbd4aca67d57ff703b8ec4ac42dc3ec4);
#
#
#
#         marker_837e8a2fdfd5686c7e46b397655e7101.bindPopup(popup_271028ee45f3d1fb0f3f56ee4ef0b15c)
#         ;
#
#
#
#
#             var marker_565d31bd8184db186d086c8ee413ed61 = L.marker(
