# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま市内のコンビニを抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity='gambling' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#        osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0  5922748736   None           None             None               None
# 1  3478518455   None           None             None               None
# 2  6708221608   None           None             None               None
# 3  1150603595   None           None             None               None
# 4  6283623693   None           None             None               None
#
#   admin_level aerialway aeroway   amenity  area barrier bicycle brand bridge  \
# 0        None      None    None  gambling  None    None    None  None   None
# 1        None      None    None  gambling  None    None    None  None   None
# 2        None      None    None  gambling  None    None    None  None   None
# 3        None      None    None  gambling  None    None    None  None   None
# 4        None      None    None  gambling  None    None    None  None   None
#
#   boundary building capital construction covered culvert cutting denomination  \
# 0     None     None    None         None    None    None    None         None
# 1     None     None    None         None    None    None    None         None
# 2     None     None    None         None    None    None    None         None
# 3     None     None    None         None    None    None    None         None
# 4     None     None    None         None    None    None    None         None
#
#   disused   ele embankment  foot generator:source harbour highway historic  \
# 0    None  None       None  None             None    None    None     None
# 1    None  None       None  None             None    None    None     None
# 2    None  None       None  None             None    None    None     None
# 3    None  None       None  None             None    None    None     None
# 4    None  None       None  None             None    None    None     None
#
#   horse intermittent junction landuse layer leisure  lock man_made military  \
# 0  None         None     None    None  None    None  None     None     None
# 1  None         None     None    None  None    None  None     None     None
# 2  None         None     None    None  None    None  None     None     None
# 3  None         None     None    None  None    None  None     None     None
# 4  None         None     None    None  None    None  None     None     None
#
#   motorcar       name natural office oneway operator place   poi population  \
# 0     None       ガーデン    None   None   None     None  None  None       None
# 1     None    チンジャラ会館    None   None   None     None  None  None       None
# 2     None  MEGA GAIA    None   None   None     None  None  None       None
# 3     None   パチンコことぶき    None   None   None     None  None  None       None
# 4     None   kotobuki    None   None   None     None  None  None       None
#
#   power power_source public_transport railway   ref religion route service  \
# 0  None         None             None    None  None     None  None    None
# 1  None         None             None    None  None     None  None    None
# 2  None         None             None    None  None     None  None    None
# 3  None         None             None    None  None     None  None    None
# 4  None         None             None    None  None     None  None    None
#
#    shop sport surface  toll tourism tower:type tunnel water waterway wetland  \
# 0  None  None    None  None    None       None   None  None     None    None
# 1  None  None    None  None    None       None   None  None     None    None
# 2  None  None    None  None    None       None   None  None     None    None
# 3  None  None    None  None    None       None   None  None     None    None
# 4  None  None    None  None    None       None   None  None     None    None
#
#   width  wood z_order                               way
# 0  None  None    None  POINT (15546792.576 4294596.136)
# 1  None  None    None  POINT (15548037.284 4293725.683)
# 2  None  None    None  POINT (15553385.874 4292964.572)
# 3  None  None    None  POINT (15542648.196 4287627.388)
# 4  None  None    None   POINT (15542343.448 4283326.39)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a33ed8c8084ca8db62a46c1b44a35240 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a33ed8c8084ca8db62a46c1b44a35240&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a33ed8c8084ca8db62a46c1b44a35240 = L.map(
#                 &quot;map_a33ed8c8084ca8db62a46c1b44a35240&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3792f2d761c179e6ac37311fa4077ebe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3792f2d761c179e6ac37311fa4077ebe.addTo(map_a33ed8c8084ca8db62a46c1b44a35240);
#
#
#             var marker_a43e114eef4371bde2d00cdfcd8acc66 = L.marker(
#                 [35.95619929973122, 139.6592139],
#                 {
# }
#             ).addTo(map_a33ed8c8084ca8db62a46c1b44a35240);
#
#
#         var popup_7baded832a86ed3be42382403efc0dfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a93b6ad4284f257207d632f957a15f6 = $(`&lt;div id=&quot;html_2a93b6ad4284f257207d632f957a15f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ガーデン&lt;/div&gt;`)[0];
#                 popup_7baded832a86ed3be42382403efc0dfc.setContent(html_2a93b6ad4284f257207d632f957a15f6);
#
#
#
#         marker_a43e114eef4371bde2d00cdfcd8acc66.bindPopup(popup_7baded832a86ed3be42382403efc0dfc)
#         ;
#
#
#
#
#             var marker_f3ffe6615879b21eb79ca61ce705c370 = L.marker(
#                 [35.94986949973059, 139.6703953],
#                 {
# }
#             ).addTo(map_a33ed8c8084ca8db62a46c1b44a35240);
#
#
#         var popup_ccb9c4413e75e019ad5bac3da4627039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3090aa86f5af48679ce40d36df6c876 = $(`&lt;div id=&quot;html_d3090aa86f5af48679ce40d36df6c876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;チンジャラ会館&lt;/div&gt;`)[0];
#                 popup_ccb9c4413e75e019ad5bac3da4627039.setContent(html_d3090aa86f5af48679ce40d36df6c876);
#
#
#
#         marker_f3ffe6615879b21eb79ca61ce705c370.bindPopup(popup_ccb9c4413e75e019ad5bac3da4627039)
#         ;
#
#
#
#
#             var marker_08311fb876a35985258ff8e32b53ea4f = L.marker(
#                 [35.94433439973006, 139.7184425],
#                 {
# }
#             ).addTo(map_a33ed8c8084ca8db62a46c1b44a35240);
#
#
#         var popup_664cad6e7fecb1fc4beab90b986c1bcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9c6122233c6d41ea2119ec08c8f2230 = $(`&lt;div id=&quot;html_a9c6122233c6d41ea2119ec08c8f2230&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MEGA GAIA&lt;/div&gt;`)[0];
#                 popup_664cad6e7fecb1fc4beab90b986c1bcc.setContent(html_a9c6122233c6d41ea2119ec08c8f2230);
#
#
#
#         marker_08311fb876a35985258ff8e32b53ea4f.bindPopup(popup_664cad6e7fecb1fc4beab90b986c1bcc)
#         ;
#
#
#
#
#             var marker_c0e58a92d1a9cf5fcb150931c5931a37 = L.marker(
#                 [35.90550939972628, 139.62198429999998],
#                 {
# }
#             ).addTo(map_a33ed8c8084ca8db62a46c1b44a35240);
#
#
#         var popup_e84a4c36ac7bccbc6a3cc4082be05fd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2172cb10877baf81a6a31a408df1619 = $(`&lt;div id=&quot;html_c2172cb10877baf81a6a31a408df1619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;パチンコことぶき&lt;/div&gt;`)[0];
#                 popup_e84a4c36ac7bccbc6a3cc4082be05fd5.setContent(html_c2172cb10877baf81a6a31a408df1619);
#
#
#
#         marker_c0e58a92d1a9cf5fcb150931c5931a37.bindPopup(popup_e84a4c36ac7bccbc6a3cc4082be05fd5)
#         ;
#
#
#
#
#             var marker_5b196aa5ebcb4e03d157d85b7b732c0b = L.marker(
#                 [35.87420819972326, 139.6192467],
#                 {
# }
#             ).addTo(map_a33ed8c8084ca8db62a46c1b44a35240);
#
#
#         var popup_d9cf9b2b2ef2792dee9ea0bb4b057148 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b095927b28eb5d581187021caac2388 = $(`&lt;div id=&quot;html_8b095927b28eb5d581187021caac2388&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;kotobuki&lt;/div&gt;`)[0];
#                 popup_d9cf9b2b2ef2792dee9ea0bb4b057148.setContent(html_8b095927b28eb5d581187021caac2388);
#
#
#
#         marker_5b196aa5ebcb4e03d157d85b7b732c0b.bindPopup(popup_d9cf9b2b2ef2792dee9ea0bb4b057148)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none
